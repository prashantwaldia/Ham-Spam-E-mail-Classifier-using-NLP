# %%
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt

# %%
messages = pd.read_csv(r'F:\Imarticus\Datasets\spam1.csv', encoding = 'cp1252')

# %%
messages.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
messages.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    6720
# Unnamed: 3    6760
# Unnamed: 4    6768
# dtype: int64

# %%
messages.shape
# Out:
# (6776, 5)

# %%
messages = messages.iloc[:, [0,1]]
messages.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
messages.rename(columns = {'v1': 'label', 'v2':'message'}, inplace = True)
messages.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
messages.label = messages.label.replace({'ham':0, 'spam':1})
messages.head()
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
messages.message = messages.message.str.lower()
messages.head()
# Out:
#    label                                            message
# 0      0  go until jurong point, crazy.. available only ...
# 1      0                      ok lar... joking wif u oni...
# 2      1  free entry in 2 a wkly comp to win fa cup fina...
# 3      0  u dun say so early hor... u c already then say...
# 4      0  nah i don't think he goes to usf, he lives aro...

# %% [markdown]
# # Before creating the TDM i have converted the data in same(lower) case
# # lets also get rid of Stopwords and also Punctuations

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
len(stopwords.words('english'))
# Out:
# 179

# %% [markdown]
# # we have only seen the stopwords, Let's remove them now

# %%
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def text_process(mess):            ### creating a function
   
    nopunc = [char for char in mess if char  not   in string.punctuation]
    nopunc = "".join(nopunc)
    
    return [ word for word in nopunc.split() if word not in stopwords.words("english")]

# %%
messages['message'].apply(text_process)
# Out:
# 0       [go, jurong, point, crazy, available, bugis, n...
# 1                          [ok, lar, joking, wif, u, oni]
# 2       [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3           [u, dun, say, early, hor, u, c, already, say]
# 4       [nah, dont, think, goes, usf, lives, around, t...
#                               ...
# 6771    [2nd, time, tried, 2, contact, u, u, å£750, po...
# 6772                   [ì, b, going, esplanade, fr, home]
# 6773                     [pity, mood, soany, suggestions]
# 6774    [guy, bitching, acted, like, id, interested, b...
# 6775                                   [rofl, true, name]
# Name: message, Length: 6776, dtype: object

# %%
# lets build our TDM
# before building TDM, we need to get the count of every word

# %%
from sklearn.feature_extraction.text import CountVectorizer
count =    CountVectorizer(analyzer = text_process   ).fit(messages["message"])

# %%
count.vocabulary_
# Out:
# {'go': 3744,
#  'jurong': 4640,
#  'point': 6371,
#  'crazy': 2459,
#  'available': 1373,
#  'bugis': 1836,
#  'n': 5620,
#  'great': 3841,
#  'world': 9100,
#  'la': 4799,
#  'e': 2984,
#  'buffet': 1834,
#  'cine': 2174,
#  'got': 3801,
#  'amore': 1140,
#  'wat': 8863,
#  'ok': 5936,
#  'lar': 4838,
#  'joking': 4608,
#  'wif': 8996,
#  'u': 8527,
#  'oni': 5968,
#  'free': 3535,
#  'entry': 3119,
#  '2': 414,
#  'wkly': 9052,
#  'comp': 2290,
#  'win': 9010,
#  'fa': 3257,
#  'cup': 2514,
#  'final': 3381,
#  'tkts': 8304,
#  '21st': 434,
#  'may': 5283,
#  '2005': 421,
#  'text': 8143,
#  '87121': 836,
#  'receive': 6769,
#  'questionstd': 6660,
#  'txt': 8511,
#  'ratetcs': 6713,
#  'apply': 1226,
#  '08452810075over18s': 71,
#  'dun': 2970,
#  'say': 7123,
#  'early': 2991,
#  'hor': 4171,
#  'c': 1885,
#  'already': 1114,
#  'nah': 5627,
#  'dont': 2878,
#  'think': 8217,
#  'goes': 3758,
#  'usf': 8657,
#  'lives': 5000,
#  'around': 1277,
#  'though': 8236,
#  'freemsg': 3543,
#  'hey': 4067,
#  'darling': 2578,
#  '3': 518,
#  'weeks': 8916,
#  'word': 9086,
#  'back': 1424,
#  'id': 4290,
#  'like': 4950,
#  'fun': 3606,
#  'still': 7786,
#  'tb': 8073,
#  'xxx': 9225,
#  'std': 7761,
#  'chgs': 2119,
#  'send': 7217,
#  'å£150': 9363,
#  'rcv': 6725,
#  'even': 3166,
#  'brother': 1803,
#  'speak': 7633,
#  'treat': 8437,
#  'aids': 1060,
#  'patent': 6166,
#  'per': 6207,
#  'request': 6882,
#  'melle': 5326,
#  'oru': 6032,
#  'minnaminunginte': 5408,
#  'nurungu': 5865,
#  'vettam': 8720,
#  'set': 7246,
#  'callertune': 1921,
#  'callers': 1920,
#  'press': 6499,
#  '9': 874,
#  'copy': 2395,
#  'friends': 3567,
#  'winner': 9021,
#  'valued': 8691,
#  'network': 5703,
#  'customer': 2527,
#  'selected': 7203,
#  'receivea': 6770,
#  'å£900': 9404,
#  'prize': 6533,
#  'reward': 6941,
#  'claim': 2180,
#  'call': 1902,
#  '09061701461': 217,
#  'code': 2241,
#  'kl341': 4755,
#  'valid': 8687,
#  '12': 322,
#  'hours': 4190,
#  'mobile': 5466,
#  '11': 312,
#  'months': 5511,
#  'r': 6674,
#  'entitled': 3116,
#  'update': 8614,
#  'latest': 4855,
#  'colour': 2264,
#  'mobiles': 5467,
#  'camera': 1938,
#  'co': 2230,
#  '08002986030': 56,
#  'im': 4319,
#  'gonna': 3775,
#  'home': 4138,
#  'soon': 7583,
#  'want': 8842,
#  'talk': 8039,
#  'stuff': 7859,
#  'anymore': 1193,
#  'tonight': 8361,
#  'k': 4646,
#  'ive': 4514,
#  'cried': 2476,
#  'enough': 3107,
#  'today': 8321,
#  'six': 7435,
#  'chances': 2056,
#  'cash': 1999,
#  '100': 292,
#  '20000': 418,
#  'pounds': 6437,
#  'csh11': 2493,
#  '87575': 840,
#  'cost': 2408,
#  '150pday': 350,
#  '6days': 723,
#  '16': 374,
#  'tsandcs': 8472,
#  'reply': 6874,
#  'hl': 4104,
#  '4': 578,
#  'info': 4382,
#  'urgent': 8636,
#  '1': 290,
#  'week': 8911,
#  'membership': 5332,
#  'å£100000': 9357,
#  'jackpot': 4532,
#  '81010': 786,
#  'tc': 8075,
#  'wwwdbuknet': 9169,
#  'lccltd': 4872,
#  'pobox': 6350,
#  '4403ldnw1a7rw18': 599,
#  'searching': 7170,
#  'right': 6953,
#  'words': 9089,
#  'thank': 8161,
#  'breather': 1773,
#  'promise': 6572,
#  'wont': 9077,
#  'take': 8030,
#  'help': 4035,
#  'granted': 3830,
#  'fulfil': 3602,
#  'wonderful': 9074,
#  'blessing': 1644,
#  'times': 8280,
#  'date': 2587,
#  'sunday': 7927,
#  'xxxmobilemovieclub': 9226,
#  'use': 8651,
#  'credit': 2466,
#  'click': 2202,
#  'wap': 8847,
#  'link': 4973,
#  'next': 5721,
#  'message': 5357,
#  'httpwap': 4219,
#  'xxxmobilemovieclubcomnqjkgighjjgcbl': 9227,
#  'oh': 5929,
#  'kim': 4722,
#  'watching': 8868,
#  'eh': 3041,
#  'remember': 6841,
#  'spell': 7648,
#  'name': 5633,
#  'yes': 9265,
#  'v': 8679,
#  'naughty': 5659,
#  'make': 5201,
#  'wet': 8953,
#  'fine': 3389,
#  'thatåõs': 8179,
#  'way': 8879,
#  'feel': 3334,
#  'gota': 3802,
#  'b': 1404,
#  'england': 3098,
#  'macedonia': 5163,
#  'miss': 5427,
#  'goalsteam': 3750,
#  'news': 5716,
#  'ur': 8633,
#  'national': 5652,
#  'team': 8089,
#  '87077': 835,
#  'eg': 3032,
#  'trywales': 8470,
#  'scotland': 7149,
#  '4txtì¼120': 643,
#  'poboxox36504w45wq': 6362,
#  'seriously': 7239,
#  'i‰û÷m': 4525,
#  'going': 3763,
#  'try': 8467,
#  'ha': 3912,
#  'ì': 9412,
#  'pay': 6177,
#  'first': 3409,
#  'da': 2543,
#  'stock': 7790,
#  'comin': 2280,
#  'aft': 1022,
#  'finish': 3395,
#  'lunch': 5129,
#  'str': 7817,
#  'lor': 5056,
#  'ard': 1253,
#  'smth': 7521,
#  'ffffffffff': 3351,
#  'alright': 1116,
#  'meet': 5311,
#  'sooner': 7585,
#  'forced': 3486,
#  'eat': 3004,
#  'slice': 7470,
#  'really': 6750,
#  'hungry': 4247,
#  'tho': 8232,
#  'sucks': 7897,
#  'mark': 5237,
#  'getting': 3703,
#  'worried': 9106,
#  'knows': 4766,
#  'sick': 7378,
#  'turn': 8493,
#  'pizza': 6300,
#  'lol': 5033,
#  'always': 1126,
#  'convincing': 2381,
#  'catch': 2011,
#  'bus': 1856,
#  'frying': 3590,
#  'egg': 3036,
#  'tea': 8083,
#  'eating': 3007,
#  'moms': 5490,
#  'left': 4894,
#  'dinner': 2786,
#  'love': 5081,
#  'amp': 1142,
#  'packing': 6090,
#  'car': 1966,
#  'ill': 4316,
#  'let': 4917,
#  'know': 4762,
#  'theres': 8202,
#  'room': 6998,
#  'ahhh': 1051,
#  'work': 9092,
#  'vaguely': 8682,
#  'wait': 8812,
#  'thats': 8178,
#  'clear': 2196,
#  'sure': 7955,
#  'sarcastic': 7100,
#  'x': 9206,
#  'doesnt': 2850,
#  'live': 4996,
#  'us': 8647,
#  'yeah': 9252,
#  'apologetic': 1214,
#  'fallen': 3284,
#  'actin': 961,
#  'spoilt': 7676,
#  'child': 2135,
#  'caught': 2015,
#  'till': 8275,
#  'badly': 1430,
#  'cheers': 2101,
#  'tell': 8108,
#  'anything': 1199,
#  'fear': 3326,
#  'fainting': 3274,
#  'housework': 4195,
#  'quick': 6661,
#  'cuppa': 2516,
#  'thanks': 8162,
#  'subscription': 7886,
#  'ringtone': 6962,
#  'uk': 8542,
#  'charged': 2068,
#  'å£5month': 9396,
#  'please': 6329,
#  'confirm': 2336,
#  'replying': 6876,
#  'yup': 9336,
#  'look': 5044,
#  'timings': 8287,
#  'msg': 5553,
#  'xuhui': 9221,
#  'learn': 4883,
#  '2nd': 493,
#  'lesson': 4915,
#  '8am': 863,
#  'oops': 5986,
#  'roommates': 7001,
#  'done': 2875,
#  'see': 7187,
#  'letter': 4919,
#  'decide': 2641,
#  'hello': 4028,
#  'hows': 4202,
#  'saturday': 7114,
#  'texting': 8151,
#  'youd': 9299,
#  'decided': 2642,
#  'tomo': 8346,
#  'trying': 8469,
#  'invite': 4446,
#  'pls': 6337,
#  'ahead': 1049,
#  'watts': 8877,
#  'wanted': 8844,
#  'weekend': 8913,
#  'abiola': 913,
#  'forget': 3492,
#  'need': 5678,
#  'crave': 2456,
#  'sweet': 7986,
#  'arabian': 1250,
#  'steed': 7768,
#  'mmmmmm': 5456,
#  'yummy': 9331,
#  '07732584351': 29,
#  'rodger': 6987,
#  'burns': 1853,
#  'tried': 8446,
#  'sms': 7515,
#  'nokia': 5785,
#  'camcorder': 1936,
#  '08000930705': 52,
#  'delivery': 2680,
#  'tomorrow': 8349,
#  'seeing': 7189,
#  'hope': 4162,
#  'man': 5211,
#  'well': 8930,
#  'endowed': 3088,
#  'ltgt': 5114,
#  'inches': 4350,
#  'callsmessagesmissed': 1929,
#  'calls': 1927,
#  'didnt': 2754,
#  'get': 3695,
#  'hep': 4049,
#  'immunisation': 4331,
#  'nigeria': 5734,
#  'fair': 3275,
#  'hopefully': 4166,
#  'tyler': 8521,
#  'cant': 1955,
#  'could': 2420,
#  'maybe': 5285,
#  'ask': 1305,
#  'bit': 1619,
#  'stubborn': 7848,
#  'hospital': 4178,
#  'kept': 4693,
#  'telling': 8109,
#  'weak': 8885,
#  'sucker': 7895,
#  'hospitals': 4179,
#  'suckers': 7896,
#  'thinked': 8218,
#  'time': 8277,
#  'saw': 7122,
#  'class': 2188,
#  'gram': 3822,
#  'usually': 8668,
#  'runs': 7044,
#  'half': 3929,
#  'eighth': 3044,
#  'smarter': 7493,
#  'gets': 3699,
#  'almost': 1110,
#  'whole': 8985,
#  'second': 7174,
#  'fyi': 3621,
#  'ride': 6952,
#  'morning': 5520,
#  'hes': 4062,
#  'crashing': 2455,
#  'place': 6302,
#  'wow': 9125,
#  'never': 5707,
#  'realized': 6748,
#  'embarassed': 3069,
#  'accomodations': 941,
#  'thought': 8237,
#  'liked': 4951,
#  'since': 7405,
#  'best': 1573,
#  'seemed': 7193,
#  'happy': 3963,
#  'cave': 2019,
#  'sorry': 7595,
#  'give': 3725,
#  'offered': 5909,
#  'embarassing': 3070,
#  'ac': 927,
#  'sptv': 7699,
#  'new': 5711,
#  'jersey': 4575,
#  'devils': 2733,
#  'detroit': 2727,
#  'red': 6793,
#  'wings': 9019,
#  'play': 6318,
#  'ice': 4285,
#  'hockey': 4122,
#  'correct': 2400,
#  'incorrect': 4361,
#  'end': 3084,
#  'mallika': 5210,
#  'sherawat': 7300,
#  'yesterday': 9280,
#  'find': 3386,
#  'lturlgt': 5117,
#  'congrats': 2343,
#  'year': 9254,
#  'special': 7635,
#  'cinema': 2175,
#  'pass': 6154,
#  '09061209465': 212,
#  'suprman': 7953,
#  'matrix3': 5270,
#  'starwars3': 7748,
#  'etc': 3152,
#  'bx420ip45we': 1878,
#  '150pm': 351,
#  'later': 4853,
#  'meeting': 5314,
#  'reached': 6731,
#  'yesgauti': 9273,
#  'sehwag': 7200,
#  'odi': 5903,
#  'series': 7237,
#  'pick': 6270,
#  'burger': 1848,
#  'move': 5538,
#  'pain': 6097,
#  'killing': 4719,
#  'good': 3777,
#  'joke': 4603,
#  'girls': 3722,
#  'situation': 7431,
#  'seekers': 7190,
#  'part': 6141,
#  'checking': 2095,
#  'iq': 4461,
#  'took': 8367,
#  'forever': 3489,
#  'come': 2272,
#  'double': 2893,
#  'check': 2091,
#  'hair': 3924,
#  'dresser': 2927,
#  'said': 7069,
#  'wun': 9155,
#  'cut': 2531,
#  'short': 7340,
#  'nice': 5727,
#  'pleased': 6330,
#  'advise': 1005,
#  'following': 3468,
#  'recent': 6773,
#  'review': 6939,
#  'mob': 5464,
#  'awarded': 1392,
#  'å£1500': 9364,
#  'bonus': 1688,
#  '09066364589': 261,
#  'song': 7577,
#  'dedicated': 2652,
#  'day': 2599,
#  'dedicate': 2651,
#  'valuable': 8689,
#  'frnds': 3576,
#  'rply': 7017,
#  'complimentary': 2309,
#  'trip': 8447,
#  'eurodisinc': 3159,
#  'trav': 8429,
#  'acoentry41': 956,
#  'å£1000': 9355,
#  'dis': 2799,
#  '186å£150morefrmmob': 383,
#  'shracomorsglsuplt10': 7364,
#  'ls1': 5103,
#  '3aj': 551,
#  'hear': 4004,
#  'divorce': 2828,
#  'barbie': 1460,
#  'comes': 2276,
#  'kens': 4691,
#  'plane': 6309,
#  'month': 5507,
#  'wah': 8805,
#  'lucky': 5122,
#  'save': 7118,
#  'money': 5495,
#  'hee': 4020,
#  'finished': 3397,
#  'hi': 4073,
#  'babe': 1413,
#  'wanna': 8840,
#  'something': 7563,
#  'xx': 9222,
#  'kkwhere': 4752,
#  'youhow': 9302,
#  'performed': 6214,
#  'waiting': 8816,
#  'machan': 5165,
#  'cool': 2387,
#  'gentleman': 3686,
#  'dignity': 2776,
#  'respect': 6903,
#  'peoples': 6206,
#  'much': 5573,
#  'shy': 7373,
#  'pa': 6085,
#  'operate': 5993,
#  'looking': 5048,
#  'job': 4590,
#  'tas': 8057,
#  'earn': 2992,
#  'ah': 1047,
#  'stop': 7800,
#  'urgnt': 8640,
#  'real': 6741,
#  'yo': 9290,
#  'tickets': 8266,
#  'one': 5964,
#  'jacket': 4531,
#  'used': 8652,
#  'multis': 5584,
#  'started': 7741,
#  'requests': 6883,
#  'came': 1937,
#  'bed': 1529,
#  'coins': 2248,
#  'factory': 3265,
#  'gotta': 3806,
#  'nitros': 5757,
#  'ela': 3049,
#  'kanoil': 4668,
#  'download': 2901,
#  'wen': 8936,
#  'don‰û÷t': 2883,
#  'stand': 7729,
#  'close': 2209,
#  'you‰û÷ll': 9323,
#  'another': 1177,
#  'night': 5736,
#  'spent': 7653,
#  'late': 4848,
#  'afternoon': 1024,
#  'casualty': 2009,
#  'means': 5297,
#  'havent': 3985,
#  'stuff42moro': 7860,
#  'includes': 4354,
#  'sheets': 7295,
#  'smile': 7502,
#  'pleasure': 6332,
#  'trouble': 8453,
#  'pours': 6439,
#  'rain': 6686,
#  'sum1': 7918,
#  'hurts': 4261,
#  'becoz': 1527,
#  'someone': 7556,
#  'loves': 5091,
#  'smiling': 7506,
#  'service': 7242,
#  'representative': 6880,
#  '0800': 48,
#  '169': 376,
#  '6031': 691,
#  '10am9pm': 306,
#  'guaranteed': 3879,
#  'å£5000': 9391,
#  'planning': 6314,
#  'buy': 1868,
#  'lido': 4932,
#  '530': 663,
#  'show': 7355,
#  'collected': 2257,
#  'simply': 7402,
#  'password': 6162,
#  'mix': 5447,
#  '85069': 821,
#  'verify': 8716,
#  'usher': 8659,
#  'britney': 1793,
#  'fml': 3458,
#  'telugu': 8114,
#  'moviewat': 5543,
#  'abt': 922,
#  'loads': 5010,
#  'loans': 5012,
#  'wk': 9048,
#  'hols': 4136,
#  'run': 7041,
#  'forgot': 3497,
#  'hairdressers': 3926,
#  'appointment': 1230,
#  'four': 3516,
#  'shower': 7357,
#  'beforehand': 1542,
#  'cause': 2016,
#  'prob': 6539,
#  'ham': 3935,
#  'nothing': 5819,
#  'else': 3063,
#  'okay': 5937,
#  'price': 6512,
#  'long': 5040,
#  'legal': 4897,
#  'ave': 1379,
#  'ams': 1146,
#  'gone': 3772,
#  '4the': 640,
#  'driving': 2936,
#  'test': 8137,
#  'yet': 9281,
#  'youre': 9312,
#  'mean': 5293,
#  'guess': 3887,
#  'gave': 3656,
#  'boston': 1710,
#  'men': 5337,
#  'changed': 2058,
#  'search': 7169,
#  'location': 5015,
#  'nyc': 5875,
#  'cuz': 2538,
#  'signin': 7390,
#  'page': 6093,
#  'says': 7127,
#  'umma': 8551,
#  'life': 4935,
#  'vava': 8703,
#  'lot': 5066,
#  'dear': 2623,
#  'wishes': 9033,
#  'birthday': 1617,
#  'making': 5205,
#  'truly': 8461,
#  'memorable': 5334,
#  'aight': 1062,
#  'hit': 4095,
#  'would': 9121,
#  'ip': 4454,
#  'address': 980,
#  'considering': 2354,
#  'computer': 2316,
#  'isnt': 4480,
#  'minecraft': 5404,
#  'server': 7241,
#  'grumpy': 3872,
#  'old': 5954,
#  'people': 6205,
#  'mom': 5487,
#  'better': 1581,
#  'lying': 5145,
#  'jokes': 4605,
#  'worry': 9109,
#  'busy': 1862,
#  'plural': 6342,
#  'noun': 5828,
#  'research': 6889,
#  'dinnermsg': 2787,
#  'cos': 2406,
#  'things': 8216,
#  'scared': 7134,
#  'mah': 5189,
#  'loud': 5076,
#  'gent': 3684,
#  'contact': 2359,
#  'last': 4845,
#  'weekends': 8914,
#  'draw': 2915,
#  'shows': 7363,
#  '09064012160': 236,
#  'k52': 4647,
#  '12hrs': 333,
#  '150ppm': 361,
#  'wa': 8800,
#  'openin': 5990,
#  'sentence': 7230,
#  'formal': 3500,
#  'anyway': 1203,
#  'juz': 4645,
#  'tt': 8479,
#  'eatin': 3006,
#  'puttin': 6637,
#  'weighthaha': 8921,
#  'anythin': 1198,
#  'happened': 3955,
#  'entered': 3109,
#  'cabin': 1888,
#  'bday': 1512,
#  'boss': 1709,
#  'felt': 3343,
#  'askd': 1306,
#  'invited': 4447,
#  'apartment': 1208,
#  'went': 8939,
#  'specially': 7639,
#  'holiday': 4132,
#  'flights': 3435,
#  'inc': 4348,
#  'operator': 5994,
#  '0871277810910pmin': 121,
#  '18': 379,
#  'goodo': 3791,
#  'must': 5604,
#  'friday': 3560,
#  'eggpotato': 3037,
#  'ratio': 6715,
#  'tortilla': 8386,
#  'needed': 5680,
#  'hmmmy': 4117,
#  'uncle': 8558,
#  'informed': 4386,
#  'paying': 6182,
#  'school': 7140,
#  'directly': 2793,
#  'food': 3475,
#  'private': 6530,
#  '2004': 420,
#  'account': 945,
#  'statement': 7751,
#  '07742676969': 31,
#  '786': 753,
#  'unredeemed': 8600,
#  'points': 6372,
#  '08719180248': 169,
#  'identifier': 4297,
#  '45239': 611,
#  'expires': 3235,
#  'å£2000': 9376,
#  'caller': 1919,
#  '5903': 668,
#  'landline': 4825,
#  '09064019788': 242,
#  'box42wr29c': 1736,
#  'applespairsall': 1224,
#  'malarky': 5207,
#  'todays': 8327,
#  'voda': 8769,
#  'numbers': 5861,
#  'ending': 3086,
#  '7548': 748,
#  '350': 541,
#  'award': 1391,
#  'match': 5258,
#  '08712300220': 103,
#  'quoting': 6673,
#  '4041': 583,
#  'standard': 7730,
#  'rates': 6712,
#  'app': 1218,
#  'sao': 7094,
#  'mu': 5572,
#  'ìï': 9415,
#  'predict': 6474,
#  'ìll': 9413,
#  'buying': 1871,
#  'knowyetunde': 4769,
#  'hasnt': 3975,
#  'sent': 7228,
#  'bother': 1712,
#  'sending': 7220,
#  'involve': 4451,
#  'shouldnt': 7349,
#  'imposed': 4337,
#  'apologise': 1215,
#  'girl': 3718,
#  'del': 2670,
#  'bak': 1438,
#  'sum': 7917,
#  'lucyxx': 5126,
#  'kkhow': 4746,
#  'tmorrowpls': 8309,
#  'accomodate': 940,
#  'answer': 1180,
#  'question': 6657,
#  'sunshine': 7934,
#  'quiz': 6668,
#  'q': 6643,
#  'top': 8376,
#  'sony': 7580,
#  'dvd': 2979,
#  'player': 6320,
#  'country': 2427,
#  'algarve': 1091,
#  'ansr': 1179,
#  '82277': 792,
#  'sptyrone': 7700,
#  'laid': 4816,
#  'dogging': 2857,
#  'locations': 5016,
#  'direct': 2792,
#  'join': 4598,
#  'uks': 8545,
#  'largest': 4842,
#  'bt': 1820,
#  'txting': 8516,
#  'gravel': 3835,
#  '69888': 717,
#  'nt': 5849,
#  'ec2a': 3009,
#  '31pmsg150p': 534,
#  'haf': 3918,
#  'msn': 5565,
#  'yijuehotmailcom': 9287,
#  'rooms': 7002,
#  'befor': 1541,
#  'activities': 967,
#  'youll': 9306,
#  'msgs': 5557,
#  'chat': 2080,
#  'svc': 7971,
#  'hardcore': 3965,
#  'services': 7243,
#  '69988': 721,
#  'age': 1032,
#  'yr': 9327,
#  'lazy': 4871,
#  'type': 8523,
#  'lect': 4891,
#  'pouch': 6434,
#  'sir': 7417,
#  'mail': 5192,
#  'swt': 8000,
#  'nver': 5870,
#  'tired': 8290,
#  'little': 4995,
#  'lovable': 5080,
#  'persons': 6232,
#  'cozsomtimes': 2441,
#  'occupy': 5896,
#  'biggest': 1598,
#  'hearts': 4012,
#  'gud': 3881,
#  'ni8': 5724,
#  'open': 5987,
#  'ya': 9236,
#  'dot': 2892,
#  'whats': 8962,
#  'staff': 7720,
#  'taking': 8036,
#  'replied': 6872,
#  'randy': 6705,
#  'sexy': 7259,
#  'female': 3344,
#  'local': 5014,
#  'luv': 5135,
#  'netcollex': 5699,
#  'ltd': 5109,
#  '08700621170150p': 73,
#  'ummmawill': 8552,
#  'inour': 4403,
#  'begin': 1547,
#  'qatar': 6644,
#  'pray': 6467,
#  'hard': 3964,
#  'ki': 4707,
#  'deleted': 2674,
#  'sindu': 7407,
#  'birla': 1613,
#  'soft': 7543,
#  'wine': 9017,
#  'flowing': 3449,
#  'nevering': 5708,
#  'thk': 8226,
#  'plaza': 6327,
#  'typical': 8526,
#  'everywhere': 3185,
#  'dirt': 2796,
#  'floor': 3443,
#  'windows': 9014,
#  'shirt': 7314,
#  'sometimes': 7567,
#  'mouth': 5537,
#  'dream': 2919,
#  'without': 9042,
#  'chores': 2161,
#  'joy': 4620,
#  'lots': 5069,
#  'tv': 8498,
#  'exist': 3219,
#  'hail': 3923,
#  'mist': 5438,
#  'become': 1525,
#  'aaooooright': 902,
#  'leaving': 4890,
#  'house': 4191,
#  'interview': 4433,
#  'boy': 1741,
#  'meare': 5300,
#  'missing': 5431,
#  'annoncement': 1170,
#  'years': 9255,
#  '07046744435': 22,
#  'arrange': 1281,
#  '0871277810810': 120,
#  'keep': 4685,
#  'safe': 7064,
#  'envy': 3123,
#  'everyone': 3179,
#  'sees': 7197,
#  'parentsi': 6133,
#  'hand': 3938,
#  'excited': 3207,
#  'spend': 7651,
#  'bootydelious': 1701,
#  '32f': 539,
#  'inviting': 4448,
#  'friend': 3565,
#  'yes434': 9267,
#  'no434': 5764,
#  'wwwsmsacubootydelious': 9189,
#  'frnd': 3575,
#  '62468': 699,
#  'bangbabes': 1452,
#  'order': 6018,
#  'content': 2363,
#  'goto': 3805,
#  'bangb': 1451,
#  'internetservice': 4432,
#  'menu': 5345,
#  'cultures': 2510,
#  'module': 5480,
#  '09061701939': 219,
#  's89': 7054,
#  'avoid': 1385,
#  'missunderstding': 5436,
#  'wit': 9038,
#  'beloved': 1563,
#  'ones': 5966,
#  'escape': 3142,
#  'fancy': 3296,
#  'bridge': 1778,
#  'needs': 5684,
#  'lager': 4815,
#  'completely': 2305,
#  'formclark': 3504,
#  'also': 1120,
#  'utter': 8670,
#  'waste': 8860,
#  'axis': 1399,
#  'bank': 1454,
#  'hmmm': 4111,
#  'hop': 4161,
#  'muz': 5610,
#  'discuss': 2812,
#  'liao': 4924,
#  'coming': 2281,
#  'bloody': 1659,
#  'hell': 4026,
#  'believe': 1554,
#  'surname': 7961,
#  ...}

# %%
len(count.vocabulary_)

# count of total number of unique words
# which means if i convert into TDM, TDM should have 9422 cols
# Out:
# 9422

# %%
tdm = count.transform(messages.message)

# creating the term document matrix

# %%
tdm.shape
# Out:
# (6776, 9422)

# %%
type(tdm)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(tdm, messages.label)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (5082, 9422)
# (5082,)

# %%
from sklearn.naive_bayes import MultinomialNB

nb_spam = MultinomialNB()

# %%
nb_spam.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
pred = nb_spam.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
tab1 = confusion_matrix(y_test, pred)
tab1
# Out:
# array([[1429,   20],
#        [  15,  230]], dtype=int64)

# %%
tab1.diagonal().sum()*100 / tab1.sum()
# Out:
# 97.93388429752066

# %%
from wordcloud import WordCloud  

cloud  = WordCloud(stopwords = stopwords.words("english"), max_words= 50).generate(str(messages['message']) )
plt.figure(figsize=(10 , 10)) 
plt.imshow(cloud)

# %%
spam_df = messages[messages.label == 1]

# %%
ham_df = messages[messages.label == 0]

# %%
cloud  = WordCloud(stopwords = stopwords.words("english"), max_words= 50).generate(str(spam_df['message']) )
plt.figure(figsize=(10 , 10)) 
plt.imshow(cloud)

# %%
cloud  = WordCloud(stopwords = stopwords.words("english"), max_words= 50).generate(str(ham_df['message']) )
plt.figure(figsize=(10 , 10)) 
plt.imshow(cloud)
